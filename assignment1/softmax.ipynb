# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = "D:\\vscode_Python\\cifar-10-batches-py"
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 0.004490
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.001782 analytic: -0.001782, relative error: 1.068922e-10
# numerical: 0.007505 analytic: 0.007505, relative error: 1.135340e-08
# numerical: -0.000961 analytic: -0.000961, relative error: 6.296650e-10
# numerical: -0.011101 analytic: -0.011101, relative error: 2.774949e-08
# numerical: 0.003187 analytic: 0.003187, relative error: 6.285228e-09
# numerical: -0.010237 analytic: -0.010237, relative error: 5.754332e-08
# numerical: -0.009722 analytic: -0.009722, relative error: 5.231135e-08
# numerical: 0.006438 analytic: 0.006438, relative error: 2.552122e-08
# numerical: -0.008607 analytic: -0.008607, relative error: 3.068756e-08
# numerical: -0.010812 analytic: -0.010812, relative error: 7.126636e-08
# numerical: 0.132093 analytic: 0.132093, relative error: 1.863502e-09
# numerical: -0.017571 analytic: -0.017571, relative error: 4.971868e-08
# numerical: -0.042301 analytic: -0.042301, relative error: 4.238288e-08
# numerical: -0.019352 analytic: -0.019352, relative error: 2.980165e-08
# numerical: 0.146910 analytic: 0.146910, relative error: 4.526000e-09
# numerical: -0.018749 analytic: -0.018749, relative error: 1.288574e-11
# numerical: -0.020552 analytic: -0.020552, relative error: 2.891241e-08
# numerical: 0.194518 analytic: 0.194518, relative error: 7.465869e-09
# numerical: 0.016750 analytic: 0.016750, relative error: 6.254452e-08
# numerical: 0.140206 analytic: 0.140206, relative error: 4.462180e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.396940e+00 computed in 0.082078s
# vectorized loss: 2.396940e+00 computed in 0.002993s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax

results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = list(np.arange(2.5e4, 5e4,100))

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for rs in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train,
                      y_train,
                      learning_rate=lr,
                      reg=rs,
                      num_iters=1500,
                      verbose=True)  #! 进行训练
        #* 训练集
        y_train_predict = softmax.predict(X_train)
        y_train_acc = np.mean(y_train_predict == y_train)
        #* 验证集
        y_val_predict = softmax.predict(X_val)
        y_val_acc = np.mean(y_val_predict == y_val)
        #* 存储结果
        results[(lr, rs)] = (y_train_acc, y_val_acc)

        if y_val_acc > best_val:
            best_val = y_val_acc
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' %
          (lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved during cross-validation: %f' %
      best_val)
# Out:
# iteration 0 / 1500: loss 767.949373
# iteration 100 / 1500: loss 281.806990
# iteration 200 / 1500: loss 104.360190
# iteration 300 / 1500: loss 39.555809
# iteration 400 / 1500: loss 15.838105
# iteration 500 / 1500: loss 7.202466
# iteration 600 / 1500: loss 3.968420
# iteration 700 / 1500: loss 2.732055
# iteration 800 / 1500: loss 2.349999
# iteration 900 / 1500: loss 2.153588
# iteration 1000 / 1500: loss 2.141114
# iteration 1100 / 1500: loss 2.055394
# iteration 1200 / 1500: loss 2.083018
# iteration 1300 / 1500: loss 2.145042
# iteration 1400 / 1500: loss 2.099489
# iteration 0 / 1500: loss 764.663138
# iteration 100 / 1500: loss 279.586001
# iteration 200 / 1500: loss 103.205192
# iteration 300 / 1500: loss 38.973027
# iteration 400 / 1500: loss 15.572499
# iteration 500 / 1500: loss 6.950931
# iteration 600 / 1500: loss 3.899628
# iteration 700 / 1500: loss 2.711189
# iteration 800 / 1500: loss 2.390883
# iteration 900 / 1500: loss 2.138703
# iteration 1000 / 1500: loss 2.077892
# iteration 1100 / 1500: loss 2.045489
# iteration 1200 / 1500: loss 2.070924
# iteration 1300 / 1500: loss 2.070255
# iteration 1400 / 1500: loss 2.121935
# iteration 0 / 1500: loss 774.158430
# iteration 100 / 1500: loss 281.635786
# iteration 200 / 1500: loss 103.398415
# iteration 300 / 1500: loss 38.919239
# iteration 400 / 1500: loss 15.455434
# iteration 500 / 1500: loss 6.897730
# iteration 600 / 1500: loss 3.818263
# iteration 700 / 1500: loss 2.712619
# iteration 800 / 1500: loss 2.332703
# iteration 900 / 1500: loss 2.169647
# iteration 1000 / 1500: loss 2.121078
# iteration 1100 / 1500: loss 2.126193
# iteration 1200 / 1500: loss 2.070777
# iteration 1300 / 1500: loss 2.034168
# iteration 1400 / 1500: loss 2.053926
# iteration 0 / 1500: loss 786.375516
# iteration 100 / 1500: loss 284.886248
# iteration 200 / 1500: loss 104.500521
# iteration 300 / 1500: loss 39.119339
# iteration 400 / 1500: loss 15.450411
# iteration 500 / 1500: loss 6.876414
# iteration 600 / 1500: loss 3.836331
# iteration 700 / 1500: loss 2.730353
# iteration 800 / 1500: loss 2.348151
# iteration 900 / 1500: loss 2.205109
# iteration 1000 / 1500: loss 2.106678
# iteration 1100 / 1500: loss 2.075151
# iteration 1200 / 1500: loss 2.137612
# iteration 1300 / 1500: loss 2.130295
# iteration 1400 / 1500: loss 2.104297
# iteration 0 / 1500: loss 785.639078
# iteration 100 / 1500: loss 283.627742
# iteration 200 / 1500: loss 103.393369
# iteration 300 / 1500: loss 38.665140
# iteration 400 / 1500: loss 15.218435
# iteration 500 / 1500: loss 6.841102
# iteration 600 / 1500: loss 3.808259
# iteration 700 / 1500: loss 2.638613
# iteration 800 / 1500: loss 2.315588
# iteration 900 / 1500: loss 2.227306
# iteration 1000 / 1500: loss 2.132537
# iteration 1100 / 1500: loss 2.064969
# iteration 1200 / 1500: loss 2.109382
# iteration 1300 / 1500: loss 2.105151
# iteration 1400 / 1500: loss 2.056682
# iteration 0 / 1500: loss 789.097752
# iteration 100 / 1500: loss 283.377957
# iteration 200 / 1500: loss 102.961117
# iteration 300 / 1500: loss 38.262469
# iteration 400 / 1500: loss 15.084119
# iteration 500 / 1500: loss 6.747216
# iteration 600 / 1500: loss 3.718719
# iteration 700 / 1500: loss 2.737038
# iteration 800 / 1500: loss 2.335021
# iteration 900 / 1500: loss 2.161316
# iteration 1000 / 1500: loss 2.102499
# iteration 1100 / 1500: loss 2.087598
# iteration 1200 / 1500: loss 2.105049
# iteration 1300 / 1500: loss 2.065983
# iteration 1400 / 1500: loss 2.031956
# iteration 0 / 1500: loss 794.798319
# iteration 100 / 1500: loss 284.681598
# iteration 200 / 1500: loss 103.106331
# iteration 300 / 1500: loss 38.224041
# iteration 400 / 1500: loss 14.991548
# iteration 500 / 1500: loss 6.715042
# iteration 600 / 1500: loss 3.721202
# iteration 700 / 1500: loss 2.769784
# iteration 800 / 1500: loss 2.303922
# iteration 900 / 1500: loss 2.212120
# iteration 1000 / 1500: loss 2.178786
# iteration 1100 / 1500: loss 2.118463
# iteration 1200 / 1500: loss 2.114737
# iteration 1300 / 1500: loss 2.089282
# iteration 1400 / 1500: loss 2.045138
# iteration 0 / 1500: loss 792.150213
# iteration 100 / 1500: loss 282.578754
# iteration 200 / 1500: loss 101.957321
# iteration 300 / 1500: loss 37.645276
# iteration 400 / 1500: loss 14.764166
# iteration 500 / 1500: loss 6.547693
# iteration 600 / 1500: loss 3.700123
# iteration 700 / 1500: loss 2.670875
# iteration 800 / 1500: loss 2.345411
# iteration 900 / 1500: loss 2.148675
# iteration 1000 / 1500: loss 2.146521
# iteration 1100 / 1500: loss 2.148359
# iteration 1200 / 1500: loss 2.033577
# iteration 1300 / 1500: loss 2.092860
# iteration 1400 / 1500: loss 2.075791
# iteration 0 / 1500: loss 802.805918
# iteration 100 / 1500: loss 285.150451
# iteration 200 / 1500: loss 102.329695
# iteration 300 / 1500: loss 37.643488
# iteration 400 / 1500: loss 14.695048
# iteration 500 / 1500: loss 6.547139
# iteration 600 / 1500: loss 3.644158
# iteration 700 / 1500: loss 2.662721
# iteration 800 / 1500: loss 2.286996
# iteration 900 / 1500: loss 2.180971
# iteration 1000 / 1500: loss 2.075894
# iteration 1100 / 1500: loss 2.093039
# iteration 1200 / 1500: loss 2.044970
# iteration 1300 / 1500: loss 2.073413
# iteration 1400 / 1500: loss 2.086047
# iteration 0 / 1500: loss 811.497749
# iteration 100 / 1500: loss 287.420000
# iteration 200 / 1500: loss 102.793655
# iteration 300 / 1500: loss 37.609464
# iteration 400 / 1500: loss 14.588724
# iteration 500 / 1500: loss 6.588227
# iteration 600 / 1500: loss 3.616231
# iteration 700 / 1500: loss 2.696669
# iteration 800 / 1500: loss 2.261664
# iteration 900 / 1500: loss 2.109230
# iteration 1000 / 1500: loss 2.067983
# iteration 1100 / 1500: loss 2.140171
# iteration 1200 / 1500: loss 2.122760
# iteration 1300 / 1500: loss 2.049532
# iteration 1400 / 1500: loss 2.071597
# iteration 0 / 1500: loss 816.297802
# iteration 100 / 1500: loss 287.909590
# iteration 200 / 1500: loss 102.574619
# iteration 300 / 1500: loss 37.312786
# iteration 400 / 1500: loss 14.580142
# iteration 500 / 1500: loss 6.411347
# iteration 600 / 1500: loss 3.665227
# iteration 700 / 1500: loss 2.617251
# iteration 800 / 1500: loss 2.333317
# iteration 900 / 1500: loss 2.186755
# iteration 1000 / 1500: loss 2.157748
# iteration 1100 / 1500: loss 2.095397
# iteration 1200 / 1500: loss 2.093588
# iteration 1300 / 1500: loss 2.122468
# iteration 1400 / 1500: loss 2.119260
# iteration 0 / 1500: loss 810.464043
# iteration 100 / 1500: loss 284.738377
# iteration 200 / 1500: loss 100.938392
# iteration 300 / 1500: loss 36.761076
# iteration 400 / 1500: loss 14.230721
# iteration 500 / 1500: loss 6.303789
# iteration 600 / 1500: loss 3.625643
# iteration 700 / 1500: loss 2.593510
# iteration 800 / 1500: loss 2.253934
# iteration 900 / 1500: loss 2.153057
# iteration 1000 / 1500: loss 2.146156
# iteration 1100 / 1500: loss 2.189000
# iteration 1200 / 1500: loss 2.148609
# iteration 1300 / 1500: loss 2.069394
# iteration 1400 / 1500: loss 2.103113
# iteration 0 / 1500: loss 810.188321
# iteration 100 / 1500: loss 283.107529
# iteration 200 / 1500: loss 100.093777
# iteration 300 / 1500: loss 36.312083
# iteration 400 / 1500: loss 14.027088
# iteration 500 / 1500: loss 6.246633
# iteration 600 / 1500: loss 3.559154
# iteration 700 / 1500: loss 2.531583
# iteration 800 / 1500: loss 2.264815
# iteration 900 / 1500: loss 2.198400
# iteration 1000 / 1500: loss 2.095576
# iteration 1100 / 1500: loss 2.063959
# iteration 1200 / 1500: loss 2.097404
# iteration 1300 / 1500: loss 2.043645
# iteration 1400 / 1500: loss 2.121368
# iteration 0 / 1500: loss 817.473663
# iteration 100 / 1500: loss 284.787424
# iteration 200 / 1500: loss 100.354249
# iteration 300 / 1500: loss 36.159106
# iteration 400 / 1500: loss 13.938396
# iteration 500 / 1500: loss 6.228236
# iteration 600 / 1500: loss 3.565960
# iteration 700 / 1500: loss 2.548301
# iteration 800 / 1500: loss 2.226208
# iteration 900 / 1500: loss 2.081672
# iteration 1000 / 1500: loss 2.111791
# iteration 1100 / 1500: loss 2.104853
# iteration 1200 / 1500: loss 2.085895
# iteration 1300 / 1500: loss 2.088957
# iteration 1400 / 1500: loss 2.104352
# iteration 0 / 1500: loss 829.790385
# iteration 100 / 1500: loss 287.731542
# iteration 200 / 1500: loss 100.897542
# iteration 300 / 1500: loss 36.319138
# iteration 400 / 1500: loss 13.916904
# iteration 500 / 1500: loss 6.170960
# iteration 600 / 1500: loss 3.521124
# iteration 700 / 1500: loss 2.554121
# iteration 800 / 1500: loss 2.280438
# iteration 900 / 1500: loss 2.138751
# iteration 1000 / 1500: loss 2.100761
# iteration 1100 / 1500: loss 2.114122
# iteration 1200 / 1500: loss 2.127043
# iteration 1300 / 1500: loss 2.052308
# iteration 1400 / 1500: loss 2.063821
# iteration 0 / 1500: loss 808.515218
# iteration 100 / 1500: loss 279.839492
# iteration 200 / 1500: loss 97.784828
# iteration 300 / 1500: loss 35.052671
# iteration 400 / 1500: loss 13.479792
# iteration 500 / 1500: loss 6.022278
# iteration 600 / 1500: loss 3.410639
# iteration 700 / 1500: loss 2.554092
# iteration 800 / 1500: loss 2.255732
# iteration 900 / 1500: loss 2.132307
# iteration 1000 / 1500: loss 2.053214
# iteration 1100 / 1500: loss 2.112983
# iteration 1200 / 1500: loss 2.063329
# iteration 1300 / 1500: loss 2.076024
# iteration 1400 / 1500: loss 2.052856
# iteration 0 / 1500: loss 819.906193
# iteration 100 / 1500: loss 282.460479
# iteration 200 / 1500: loss 98.214266
# iteration 300 / 1500: loss 35.065829
# iteration 400 / 1500: loss 13.451069
# iteration 500 / 1500: loss 5.951809
# iteration 600 / 1500: loss 3.377998
# iteration 700 / 1500: loss 2.558188
# iteration 800 / 1500: loss 2.254046
# iteration 900 / 1500: loss 2.157479
# iteration 1000 / 1500: loss 2.094823
# iteration 1100 / 1500: loss 2.077316
# iteration 1200 / 1500: loss 2.108960
# iteration 1300 / 1500: loss 2.155445
# iteration 1400 / 1500: loss 2.110133
# iteration 0 / 1500: loss 809.106408
# iteration 100 / 1500: loss 277.752622
# iteration 200 / 1500: loss 96.372170
# iteration 300 / 1500: loss 34.294917
# iteration 400 / 1500: loss 13.097708
# iteration 500 / 1500: loss 5.891667
# iteration 600 / 1500: loss 3.334354
# iteration 700 / 1500: loss 2.450433
# iteration 800 / 1500: loss 2.296895
# iteration 900 / 1500: loss 2.128376
# iteration 1000 / 1500: loss 2.122046
# iteration 1100 / 1500: loss 2.090829
# iteration 1200 / 1500: loss 2.087651
# iteration 1300 / 1500: loss 2.137913
# iteration 1400 / 1500: loss 2.122770
# iteration 0 / 1500: loss 828.760447
# iteration 100 / 1500: loss 282.757294
# iteration 200 / 1500: loss 97.610546
# iteration 300 / 1500: loss 34.614061
# iteration 400 / 1500: loss 13.104071
# iteration 500 / 1500: loss 5.865305
# iteration 600 / 1500: loss 3.342023
# iteration 700 / 1500: loss 2.516110
# iteration 800 / 1500: loss 2.280215
# iteration 900 / 1500: loss 2.222214
# iteration 1000 / 1500: loss 2.107416
# iteration 1100 / 1500: loss 2.104375
# iteration 1200 / 1500: loss 2.102820
# iteration 1300 / 1500: loss 2.117807
# iteration 1400 / 1500: loss 2.047865
# iteration 0 / 1500: loss 844.450439
# iteration 100 / 1500: loss 287.029298
# iteration 200 / 1500: loss 98.738600
# iteration 300 / 1500: loss 34.851638
# iteration 400 / 1500: loss 13.193443
# iteration 500 / 1500: loss 5.835880
# iteration 600 / 1500: loss 3.469352
# iteration 700 / 1500: loss 2.502606
# iteration 800 / 1500: loss 2.249195
# iteration 900 / 1500: loss 2.140740
# iteration 1000 / 1500: loss 2.110837
# iteration 1100 / 1500: loss 2.098847
# iteration 1200 / 1500: loss 2.104148
# iteration 1300 / 1500: loss 2.081724
# iteration 1400 / 1500: loss 2.126601
# iteration 0 / 1500: loss 822.667423
# iteration 100 / 1500: loss 279.037963
# iteration 200 / 1500: loss 95.584640
# iteration 300 / 1500: loss 33.558374
# iteration 400 / 1500: loss 12.786345
# iteration 500 / 1500: loss 5.713975
# iteration 600 / 1500: loss 3.387953
# iteration 700 / 1500: loss 2.471743
# iteration 800 / 1500: loss 2.212286
# iteration 900 / 1500: loss 2.147118
# iteration 1000 / 1500: loss 2.071167
# iteration 1100 / 1500: loss 2.094244
# iteration 1200 / 1500: loss 2.095601
# iteration 1300 / 1500: loss 2.118612
# iteration 1400 / 1500: loss 2.075814
# iteration 0 / 1500: loss 834.162554
# iteration 100 / 1500: loss 281.566921
# iteration 200 / 1500: loss 96.008511
# iteration 300 / 1500: loss 33.672420
# iteration 400 / 1500: loss 12.677396
# iteration 500 / 1500: loss 5.653386
# iteration 600 / 1500: loss 3.292450
# iteration 700 / 1500: loss 2.475932
# iteration 800 / 1500: loss 2.285764
# iteration 900 / 1500: loss 2.121393
# iteration 1000 / 1500: loss 2.122076
# iteration 1100 / 1500: loss 2.116595
# iteration 1200 / 1500: loss 2.081441
# iteration 1300 / 1500: loss 2.104462
# iteration 1400 / 1500: loss 2.058640
# iteration 0 / 1500: loss 841.835936
# iteration 100 / 1500: loss 282.592163
# iteration 200 / 1500: loss 95.953901
# iteration 300 / 1500: loss 33.513147
# iteration 400 / 1500: loss 12.626971
# iteration 500 / 1500: loss 5.632377
# iteration 600 / 1500: loss 3.260019
# iteration 700 / 1500: loss 2.409451
# iteration 800 / 1500: loss 2.241025
# iteration 900 / 1500: loss 2.151322
# iteration 1000 / 1500: loss 2.144797
# iteration 1100 / 1500: loss 2.088424
# iteration 1200 / 1500: loss 2.123912
# iteration 1300 / 1500: loss 2.116960
# iteration 1400 / 1500: loss 2.123148
# iteration 0 / 1500: loss 848.186959
# iteration 100 / 1500: loss 283.675519
# iteration 200 / 1500: loss 96.061642
# iteration 300 / 1500: loss 33.472067
# iteration 400 / 1500: loss 12.552108
# iteration 500 / 1500: loss 5.592258
# iteration 600 / 1500: loss 3.217141
# iteration 700 / 1500: loss 2.514613
# iteration 800 / 1500: loss 2.229271
# iteration 900 / 1500: loss 2.113968
# iteration 1000 / 1500: loss 2.113505
# iteration 1100 / 1500: loss 2.094809
# iteration 1200 / 1500: loss 2.097426
# iteration 1300 / 1500: loss 2.106583
# iteration 1400 / 1500: loss 2.129207
# iteration 0 / 1500: loss 843.566224
# iteration 100 / 1500: loss 281.400368
# iteration 200 / 1500: loss 94.775765
# iteration 300 / 1500: loss 32.971759
# iteration 400 / 1500: loss 12.297639
# iteration 500 / 1500: loss 5.551489
# iteration 600 / 1500: loss 3.253297
# iteration 700 / 1500: loss 2.509741
# iteration 800 / 1500: loss 2.132035
# iteration 900 / 1500: loss 2.138656
# iteration 1000 / 1500: loss 2.107684
# iteration 1100 / 1500: loss 2.130943
# iteration 1200 / 1500: loss 2.047501
# iteration 1300 / 1500: loss 2.074804
# iteration 1400 / 1500: loss 2.088982
# iteration 0 / 1500: loss 843.838664
# iteration 100 / 1500: loss 280.172723
# iteration 200 / 1500: loss 94.065994
# iteration 300 / 1500: loss 32.525552
# iteration 400 / 1500: loss 12.180250
# iteration 500 / 1500: loss 5.385469
# iteration 600 / 1500: loss 3.221231
# iteration 700 / 1500: loss 2.518751
# iteration 800 / 1500: loss 2.146602
# iteration 900 / 1500: loss 2.165765
# iteration 1000 / 1500: loss 2.085387
# iteration 1100 / 1500: loss 2.078466
# iteration 1200 / 1500: loss 2.025878
# iteration 1300 / 1500: loss 2.102075
# iteration 1400 / 1500: loss 2.105518
# iteration 0 / 1500: loss 855.765611
# iteration 100 / 1500: loss 283.246178
# iteration 200 / 1500: loss 94.749884
# iteration 300 / 1500: loss 32.654234
# iteration 400 / 1500: loss 12.142111
# iteration 500 / 1500: loss 5.436346
# iteration 600 / 1500: loss 3.198651
# iteration 700 / 1500: loss 2.422358
# iteration 800 / 1500: loss 2.176352
# iteration 900 / 1500: loss 2.113173
# iteration 1000 / 1500: loss 2.173982
# iteration 1100 / 1500: loss 2.089963
# iteration 1200 / 1500: loss 2.107131
# iteration 1300 / 1500: loss 2.133902
# iteration 1400 / 1500: loss 2.092643
# iteration 0 / 1500: loss 853.611699
# iteration 100 / 1500: loss 281.273366
# iteration 200 / 1500: loss 93.826808
# iteration 300 / 1500: loss 32.236236
# iteration 400 / 1500: loss 11.989249
# iteration 500 / 1500: loss 5.285362
# iteration 600 / 1500: loss 3.151752
# iteration 700 / 1500: loss 2.473188
# iteration 800 / 1500: loss 2.142339
# iteration 900 / 1500: loss 2.108352
# iteration 1000 / 1500: loss 2.109518
# iteration 1100 / 1500: loss 2.099353
# iteration 1200 / 1500: loss 2.073270
# iteration 1300 / 1500: loss 2.096334
# iteration 1400 / 1500: loss 2.073244
# iteration 0 / 1500: loss 847.919251
# iteration 100 / 1500: loss 278.365247
# iteration 200 / 1500: loss 92.522466
# iteration 300 / 1500: loss 31.673509
# iteration 400 / 1500: loss 11.719061
# iteration 500 / 1500: loss 5.249140
# iteration 600 / 1500: loss 3.118020
# iteration 700 / 1500: loss 2.432294
# iteration 800 / 1500: loss 2.237247
# iteration 900 / 1500: loss 2.074504
# iteration 1000 / 1500: loss 2.106428
# iteration 1100 / 1500: loss 2.114361
# iteration 1200 / 1500: loss 2.123834
# iteration 1300 / 1500: loss 2.063454
# iteration 1400 / 1500: loss 2.109582
# iteration 0 / 1500: loss 857.865092
# iteration 100 / 1500: loss 280.477911
# iteration 200 / 1500: loss 92.801756
# iteration 300 / 1500: loss 31.644051
# iteration 400 / 1500: loss 11.708888
# iteration 500 / 1500: loss 5.185127
# iteration 600 / 1500: loss 3.147045
# iteration 700 / 1500: loss 2.402512
# iteration 800 / 1500: loss 2.228627
# iteration 900 / 1500: loss 2.125223
# iteration 1000 / 1500: loss 2.125514
# iteration 1100 / 1500: loss 2.128854
# iteration 1200 / 1500: loss 2.084290
# iteration 1300 / 1500: loss 2.092276
# iteration 1400 / 1500: loss 2.149884
# iteration 0 / 1500: loss 876.992584
# iteration 100 / 1500: loss 285.694198
# iteration 200 / 1500: loss 93.992975
# iteration 300 / 1500: loss 31.918481
# iteration 400 / 1500: loss 11.756429
# iteration 500 / 1500: loss 5.204784
# iteration 600 / 1500: loss 3.070917
# iteration 700 / 1500: loss 2.428395
# iteration 800 / 1500: loss 2.167881
# iteration 900 / 1500: loss 2.113448
# iteration 1000 / 1500: loss 2.106378
# iteration 1100 / 1500: loss 2.122044
# iteration 1200 / 1500: loss 2.105697
# iteration 1300 / 1500: loss 2.152700
# iteration 1400 / 1500: loss 2.133131
# iteration 0 / 1500: loss 869.803574
# iteration 100 / 1500: loss 282.260946
# iteration 200 / 1500: loss 92.494016
# iteration 300 / 1500: loss 31.317868
# iteration 400 / 1500: loss 11.494973
# iteration 500 / 1500: loss 5.168179
# iteration 600 / 1500: loss 3.102255
# iteration 700 / 1500: loss 2.414448
# iteration 800 / 1500: loss 2.182376
# iteration 900 / 1500: loss 2.136682
# iteration 1000 / 1500: loss 2.100990
# iteration 1100 / 1500: loss 2.103439
# iteration 1200 / 1500: loss 2.134537
# iteration 1300 / 1500: loss 2.089058
# iteration 1400 / 1500: loss 2.089342
# iteration 0 / 1500: loss 879.066082
# iteration 100 / 1500: loss 284.089981
# iteration 200 / 1500: loss 92.645399
# iteration 300 / 1500: loss 31.254981
# iteration 400 / 1500: loss 11.478729
# iteration 500 / 1500: loss 5.089016
# iteration 600 / 1500: loss 3.109634
# iteration 700 / 1500: loss 2.364104
# iteration 800 / 1500: loss 2.180153
# iteration 900 / 1500: loss 2.118554
# iteration 1000 / 1500: loss 2.147648
# iteration 1100 / 1500: loss 2.075396
# iteration 1200 / 1500: loss 2.047351
# iteration 1300 / 1500: loss 2.055987
# iteration 1400 / 1500: loss 2.109396
# iteration 0 / 1500: loss 883.381434
# iteration 100 / 1500: loss 283.730059
# iteration 200 / 1500: loss 92.332127
# iteration 300 / 1500: loss 31.081674
# iteration 400 / 1500: loss 11.389733
# iteration 500 / 1500: loss 5.050222
# iteration 600 / 1500: loss 3.028922
# iteration 700 / 1500: loss 2.429711
# iteration 800 / 1500: loss 2.139755
# iteration 900 / 1500: loss 2.139478
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\vscode_Python\assignment1\softmax.ipynb Cell 9' in <cell line: 19>()
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=19'>20</a> for rs in regularization_strengths:
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=20'>21</a>     softmax = Softmax()
# ---> <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=21'>22</a>     softmax.train(X_train,
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=22'>23</a>                   y_train,
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=23'>24</a>                   learning_rate=lr,
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=24'>25</a>                   reg=rs,
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=25'>26</a>                   num_iters=1500,
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=26'>27</a>                   verbose=True)  #! 进行训练
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=27'>28</a>     #* 训练集
#      <a href='vscode-notebook-cell:/d%3A/vscode_Python/assignment1/softmax.ipynb#ch0000008?line=28'>29</a>     y_train_predict = softmax.predict(X_train)
#
# File d:\vscode_Python\assignment1\cs231n\classifiers\linear_classifier.py:64, in LinearClassifier.train(self, X, y, learning_rate, reg, num_iters, batch_size, verbose)
#      58 y_batch = y[indice]
#      59 #########################################################################
#      60 #                       END OF YOUR CODE                                #
#      61 #########################################################################
#      62
#      63 # evaluate loss and gradient
# ---> 64 loss, grad = self.loss(X_batch, y_batch, reg)
#      65 loss_history.append(loss)
#      67 # perform parameter update
#      68 #########################################################################
#      69 # TODO:                                                                 #
#      70 # Update the weights using the gradient and the learning rate.          #
#      71 #########################################################################
#
# File d:\vscode_Python\assignment1\cs231n\classifiers\linear_classifier.py:136, in Softmax.loss(self, X_batch, y_batch, reg)
#     135 def loss(self, X_batch, y_batch, reg):
# --> 136   return softmax_loss_vectorized(self.W, X_batch, y_batch, reg)
#
# File d:\vscode_Python\assignment1\cs231n\classifiers\softmax.py:81, in softmax_loss_vectorized(W, X, y, reg)
#      79 temp = np.exp(f) / s.reshape(N,1)
#      80 temp[range(N), y] -= 1
# ---> 81 dW = np.dot(X.T, temp)
#      83 #* 加入正则项
#      84 loss = loss / N + reg * np.sum(W * W)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.347000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
